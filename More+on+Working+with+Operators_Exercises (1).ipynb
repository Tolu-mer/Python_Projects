# %% [markdown]
# ## Comparison Operators

# %% [markdown]
# Verify that 25 is smaller than 30.

# %%
25 < 30
# Out:
# True

# %% [markdown]
# Verify that 5 multiplied by 3 is less than or equal to 5 to the power of 3.

# %%
5*3 <= 5**3
# Out:
# True

# %% [markdown]
# Verify that 100 is equal to 10 square.

# %%
100 == 10 ** 2
# Out:
# True

# %% [markdown]
# Verify that 53 is not equal to 46.

# %%
53 != 46
# Out:
# True

# %% [markdown]
# ## Logical and Identity Operators

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Check whether the following code is True or False.

# %% [markdown]
# False or not True and not False

# %%
False or not True and not False
# Out:
# False

# %% [markdown]
# True and not False and True or not False

# %%
True and not False and True or not False
# Out:
# True

# %% [markdown]
# True or False and False

# %%
True or False and False
# Out:
# True

# %% [markdown]
# False and True or False

# %%
False and True or False
# Out:
# False

# %% [markdown]
# Using an identity operator, verify that 10 is not the same as 12.

# %%
10 is not 12
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14848\2742155778.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   10 is not 12
# True

# %% [markdown]
# Using an identity operator, verify that 50 is the same as 50.

# %%
50 is 50
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14848\4077015830.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   50 is 50
# True
